# %%
import descarteslabs as dl

# EDIT AOI
box = {
    "type": "Polygon",
    "coordinates": [
        [
            [-16.981785, -70.908162],
            [-16.981785, -70.420872],
            [-17.305588, -70.908162],
            [-17.305588, -70.420872]
        ]
    ],
}

# EDIT PREDEFINED IMAGE ID's
images = [
    "fused:bare-earth:1024:0:30.0:19:-7:-62",
    "fused:bare-earth:1024:0:30.0:19:-6:-62",
    "fused:bare-earth:1024:0:30.0:19:-5:-62",
    "fused:bare-earth:1024:0:30.0:19:-7:-63",
    "fused:bare-earth:1024:0:30.0:19:-6:-63",
    "fused:bare-earth:1024:0:30.0:19:-5:-63"
]

# The Raster API call to download an image mosaic. Other parameters are available
# The file is written in to the same directory as the script.

raster_client = dl.Raster()
raster_client.raster(
    inputs=images,
    scales=[[0, 5500], [0, 5500], [0, 5500], None],
    data_type="Byte",
    save=True,
    bands = ["blue", "green", "red", "red-edge" ],
    #EDIT NAME
    outfile_basename = "Image_Layer_1",
    resolution=60,
)

# The Raster API call to download an image mosaic. Other parameters are available
# The file is written in to the same directory as the script.

raster_client = dl.Raster()
raster_client.raster(
    inputs=images,
    scales=[[0, 5500], [0, 5500], [0, 5500], None],
    data_type="Byte",
    save=True,
    bands = ["red-edge-2", "red-edge-3", "nir", "red-edge-4" ],
    #EDIT NAME
    outfile_basename = "Image_Layer_2",
    resolution=60,
)

# The Raster API call to download an image mosaic. Other parameters are available
# The file is written in to the same directory as the script.

raster_client = dl.Raster()
raster_client.raster(
    inputs=images,
    scales=[[0, 5500], [0, 5500], [0, 5500], None],
    data_type="Byte",
    save=True,
    bands = ["swir1", "swir2", "swir3", "swir4" ],
    #EDIT NAME
    outfile_basename = "Image_Layer_3",
    resolution=60,
)

# The Raster API call to download an image mosaic. Other parameters are available
# The file is written in to the same directory as the script.

raster_client = dl.Raster()
raster_client.raster(
    inputs=images,
    scales=[[0, 5500], [0, 5500], [0, 5500], None],
    data_type="Byte",
    save=True,
    bands = ["swir5", "swir6", "tir1", "tir2" ],
    #EDIT NAME
    outfile_basename = "Image_Layer_4",
    resolution=60,
)

# The Raster API call to download an image mosaic. Other parameters are available
# The file is written in to the same directory as the script.

raster_client = dl.Raster()
raster_client.raster(
    inputs=images,
    scales=[[0, 5500], [0, 5500], [0, 5500], None],
    data_type="Byte",
    save=True,
    bands = ["tir3", "tir4", "tir5", "alpha" ],
    #EDIT NAME
    outfile_basename = "Image_Layer_5",
    resolution=60,
)
# Out:
# {
#   'files': {
#     'Image_Layer_5.tif': b'II*\x00\x08...c\xac\x90\x10'
#   },
#   'metadata': {
#     'bands': ['{"product": "fused:bare-earth", "dtype": "...0, 35000.0], "id": "fused:bare-earth:tir3"}', '{"product": "fused:bare-earth", "dtype": "...0, 35000.0], "id": "fused:bare-earth:tir4"}', '{"product": "fused:bare-earth", "dtype": "...0, 35000.0], "id": "fused:bare-earth:tir5"}', '{"product": "fused:bare-earth", "dtype": "...[0.0, 1.0], "id": "fused:bare-earth:alpha"}']
#   }
# }
